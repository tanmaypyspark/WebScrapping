# %%
pip install beautifulsoup4 requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL
url = "https://x.com/search?q=chemicalstock&src=typed_query&f=live"
# "https://mmb.moneycontrol.com/"

# Use the actual forum URL
headers = {"User-Agent": "Mozilla/5.0"}

# Make the request
response = requests.get(url, headers=headers)  # ✅ Now 'response' is defined

# Check the status
print("Response Status Code:", response.status_code)

# Create the BeautifulSoup object only if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")
    print("✅ BeautifulSoup object created!")
    print(soup.prettify())  # Print the first 1000 characters of HTML
else:
    print("❌ Request failed. Cannot create soup.")
# Out:
# Response Status Code: 400
# ❌ Request failed. Cannot create soup.

# %%
elements = soup

# %%
eleme

# %%
for comment_element in elements.find_all("div", class_= self.element_selector):  # Replace class name
            # Get the comment
            comment_text = comment_element.get_text(strip=True)

# %%
def find_Comments(data, stock_name):
        ''' Find All the comments in the page'''
        elements = self.__scrape_infinite_scroll()
        logger.info("Find all the comments in the page....")
        all_comments = []

        for comment_element in elements.find_all("div", class_= self.element_selector):  # Replace class name
            # Get the comment
            comment_text = comment_element.get_text(strip=True)
            #Get the timestamp
            get_ts = comment_element.find_previous("div", class_= self.timeStamp_selector) # Replace with your timestamp class
            # Get the Author
            author = comment_element.find_previous("div", class_= self.cmd_selector).text.strip()
            if get_ts:
                timestamp_text = self.__convert_time_to_datetime(get_ts.find("div").text.strip().replace("schedule", ""))
            else:
                timestamp_text = "Timestamp not found"

            all_comments.append({"Stock": stock_name, "Comment": comment_text,'Commented By':author, "Timestamp": timestamp_text})
        
        logger.info("Successfully grab the Data!!")
        
        return all_comments

# %%
def get_forum_comments(stock_symbol):
    url = f"https://mmb.moneycontrol.com/{stock_symbol}"  # Modify as needed
    headers = {"User-Agent": "Mozilla/5.0"}  # Prevents blocking

    response = requests.get(url, headers=headers)
    print("Response Status Code:", response.status_code)  # Debugging

    if response.status_code == 200: 
        soup = BeautifulSoup(response.text, "html.parser")
        comments = []

        for comment in soup.find_all("p", class_="Markets"):
            # print('test',comment)
            comments.append(comment.get_text())  

        return comments  

    else:  
        print("❌ Failed to fetch data. Check the URL.")
        return []  
forum_comments = get_forum_comments("Indian Chemical Stocks")
# print(response.text)
print('----------')
# print(url)
# print(forum_comments)
print(soup)
# print("Top Forum Comments on Indian Chemical Stock:")
# for comment in forum_comments[:5]:
#     print("-", comment)
# Out:
# Response Status Code: 200
# ----------

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <link as="style" href="https://stat2.moneycontrol.com/mccss/headfoot/mc_header.css?v=1.11" rel="preload"/>
#   <meta charset="utf-8"/>
#   <link href="https://www.moneycontrol.com/favicon.ico" rel="icon"/>
#   <title>
#    Online Business Forum, Economics &amp; Stocks Discussion, Share Market Ideas, Questions and Answers India - MoneyControl
#   </title>
#   <meta content="India's #1 online forum for business discussion, stocks discussion, share market ideas, questions and answers on india and world economy. - MoneyControl" name="description"/>
#   <meta content="Online Business Forum, Economic Discussions, Stocks Discussion, Share Market Ideas, Stock Market FAQ" name="Keywords"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="index,follow" name="googlebot"/>
# ...

# %%
print(soup.prettify()[:2000])
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <link as="style" href="https://stat2.moneycontrol.com/mccss/headfoot/mc_header.css?v=1.11" rel="preload"/>
#   <meta charset="utf-8"/>
#   <link href="https://www.moneycontrol.com/favicon.ico" rel="icon"/>
#   <title>
#    Online Business Forum, Economics &amp; Stocks Discussion, Share Market Ideas, Questions and Answers India - MoneyControl
#   </title>
#   <meta content="India's #1 online forum for business discussion, stocks discussion, share market ideas, questions and answers on india and world economy. - MoneyControl" name="description"/>
#   <meta content="Online Business Forum, Economic Discussions, Stocks Discussion, Share Market Ideas, Stock Market FAQ" name="Keywords"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="index,follow" name="googlebot"/>
# ...

# %%
all_classes = set()
for tag in soup.find_all(class_=True):  # Find all elements with a class attribute
    all_classes.update(tag["class"])  # Add class names to the set

print("🔍 Unique class names found on the page:")
print(all_classes)
# Out:
# 🔍 Unique class names found on the page:
# ...

# %%
print(soup.prettify()[:3000])
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <link as="style" href="https://stat2.moneycontrol.com/mccss/headfoot/mc_header.css?v=1.11" rel="preload"/>
#   <meta charset="utf-8"/>
#   <link href="https://www.moneycontrol.com/favicon.ico" rel="icon"/>
#   <title>
#    Online Business Forum, Economics &amp; Stocks Discussion, Share Market Ideas, Questions and Answers India - MoneyControl
#   </title>
#   <meta content="India's #1 online forum for business discussion, stocks discussion, share market ideas, questions and answers on india and world economy. - MoneyControl" name="description"/>
#   <meta content="Online Business Forum, Economic Discussions, Stocks Discussion, Share Market Ideas, Stock Market FAQ" name="Keywords"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="index,follow" name="googlebot"/>
# ...

# %%
for div in soup.find_all("div"):
    print(div.prettify())
    print("=" * 80)
# Out:
# <div id="__next">
#  <div style="display:none">
#   <table border="0" cellpadding="0" cellspacing="0">
#    <tbody>
#     <tr>
#      <td>
#       <link href="https://www.moneycontrol.com/rss/latestnews.xml" rel="alternate" title="MoneyControl.com News" type="application/rss+xml"/>
#      </td>
#     </tr>
#    </tbody>
#   </table>
#  </div>
#  <div class="trans_wrapper">
#  </div>
#  <div class="over">
#  </div>
#  <header class="responsive_true">
#   <input class="device_characteristics" id="device_characteristics" name="device_characteristics" readonly="" style="width:25px" type="hidden" value="is_mobile=false"/>
#   <input class="cid" id="cid" name="cid" readonly="" style="width:15px" type="hidden" value="0"/>
#   <input class="page_id" id="page_id" name="page_id" readonly="" style="width:15px" type="hidden" value="mc_bigshark"/>
#   <input class="porter_convey" id="porter_convey" name="porter_convey" readonly="" style="width:25px" type="hidden" value="VDJ4a0lFMURTUT09"/>
# ...

# %%
for p in soup.find_all("p"):
    print(p.prettify())
    print("=" * 80)
# Out:
# <p class="my_account">
#  My Account
# </p>
#
# ...
# <p>
#  Follow us on:
# </p>
#
# ...

# %%
for span in soup.find_all("span"):
    print(span.prettify())
    print("=" * 80)
# Out:
# <span class="open_hamburger" title="Open">
#  <svg height="9" viewbox="0 0 16 9" width="16" xmlns="https://www.w3.org/2000/svg">
#   <defs>
#   </defs>
#   <g transform="translate(-286 -22)">
#    <rect class="hambmenu" height="1" transform="translate(286 22)" width="16">
#    </rect>
#    <rect class="hambmenu" height="1" transform="translate(286 26)" width="16">
#    </rect>
#    <rect class="hambmenu" height="1" transform="translate(286 30)" width="16">
#    </rect>
#   </g>
#  </svg>
# </span>
#
# ...
# <span class="arrow down">
# </span>
#
# ...
# <span class="arrow down">
# </span>
#
# ...
# <span class="user_icon">
#  <svg height="16" viewbox="0 0 16 16" width="16" xmlns="https://www.w3.org/2000/svg">
#   <defs>
#   </defs>
#   <g transform="translate(-1125 -9)">
#    <circle class="userictop" cx="8" cy="8" r="8" transform="translate(1125 9)">
#    </circle>
#    <g transform="translate(1127 11.21)">
# ...

# %%
comments = []
for comment in soup.find_all("div", class_="your-class-name-here"):  # Replace class name
    comments.append(comment.get_text(strip=True))  

print("📝 Top Forum Comments on Indian Chemical Stocks:")
for comment in comments[:5]:  
    print("-", comment)
# Out:
# 📝 Top Forum Comments on Indian Chemical Stocks:

# %%
html = '''<div class="example-class another-class">Hello World</div>'''  # Replace with your actual HTML
soup = BeautifulSoup(html, 'html.parser')

# Find the first div element
element = soup.find('div')

# Get the class name(s)
if element:
    print(element.get('class'))
# Out:
# ['example-class', 'another-class']

# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
pip install webdriver-manager
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
from bs4 import BeautifulSoup
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Set up Chrome options
options = Options()
options.add_argument("--headless")  # Run in headless mode (no GUI)
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# Install and start ChromeDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

# Open a test website
driver.get("https://www.google.com")
print("✅ ChromeDriver is working successfully!")

# Close the browser
driver.quit()
# Out:
# ✅ ChromeDriver is working successfully!

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
import pandas as pd

# Chemical stocks & their Moneycontrol forum URLs
chemical_stocks = {
    "Deepak Nitrite": "https://mmb.moneycontrol.com/stock-message-forum/deepak-nitrite",
    "Tata Chemicals": "https://mmb.moneycontrol.com/stock-message-forum/tata-chemicals",
    "Aarti Industries": "https://mmb.moneycontrol.com/stock-message-forum/aarti-industries",
    "SRF": "https://mmb.moneycontrol.com/stock-message-forum/srf",
}

# Set up Chrome options
options = Options()
options.add_argument("--headless")  # Run without opening browser
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# Start WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

all_comments = []

for stock, url in chemical_stocks.items():
    driver.get(url)
    time.sleep(5)  # Allow page to load

    # Parse the page source
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Find comments (Modify class name if needed)
    comments = soup.find_all('div', class_="mctxt")  

    for comment in comments:
        text = comment.text.strip()
        all_comments.append({"Stock": stock, "Comment": text})

# Close the browser
driver.quit()

# Save data to CSV
df = pd.DataFrame(all_comments)
df.to_csv("chemical_sector_sentiment_moneycontrol.csv", index=False)
print("✅ Data saved to 'chemical_sector_sentiment_moneycontrol.csv'")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File C:\ProgramData\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# ...

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(3)  # Wait for content to load
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
print(soup.prettify())  # This prints the entire HTML structure

# %%
comments = soup.find_all('div', class_="correct-class-name")

# %%
comments = soup.find_all('div')
for comment in comments:
    if "Indian Chemical Stock" in comment.text:  # Filter relevant content
        print(comment.text.strip())

# %%
for div in soup.find_all('div'):
    print(div.text.strip())

# %%
Scroll to load dynamic content
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(5)  # Wait for comments to load

# Get updated page source
soup = BeautifulSoup(driver.page_source, 'html.parser')

# Try finding comments again
comments = soup.find_all('div', class_="mctxt")
for comment in comments:
    print(comment.text.strip())

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import pandas as pd

# Setup Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode (no UI)
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")

# Start Chrome WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# List of chemical stock forums
chemical_stocks = {
    "Deepak Nitrite": "https://mmb.moneycontrol.com/stock-message-forum/deepak-nitrite",
    "Tata Chemicals": "https://mmb.moneycontrol.com/stock-message-forum/tata-chemicals",
    "Aarti Industries": "https://mmb.moneycontrol.com/stock-message-forum/aarti-industries",
    "SRF": "https://mmb.moneycontrol.com/stock-message-forum/srf",
}

all_comments = []

for stock, url in chemical_stocks.items():
    print(f"Scraping comments for {stock}...")
    
    driver.get(url)
    time.sleep(5)  # Allow page to load

    # Scroll down multiple times to load dynamic content
    for _ in range(5):  
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)

    # Parse the page with BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Try different class names
    possible_classes = ["mctxt", "content_box", "text", "post_content"]
    
    for class_name in possible_classes:
        comments = soup.find_all('div', class_=class_name)
        if comments:
            print(f"Found comments using class: {class_name}")
            break  # Stop once we find the right class

    # Extract comment text
    for comment in comments:
        text = comment.get_text(strip=True)
        all_comments.append({"Stock": stock, "Comment": text})

# Close browser
driver.quit()

# Save data to CSV
df = pd.DataFrame(all_comments)
df.to_csv("chemical_sector_sentiment.csv", index=False)

print("✅ Data saved to chemical_sector_sentiment.csv")
# Out:
# Scraping comments for Deepak Nitrite...
# Scraping comments for Tata Chemicals...
# Scraping comments for Aarti Industries...
# Scraping comments for SRF...
# ✅ Data saved to chemical_sector_sentiment.csv

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import pandas as pd

# Set up Selenium WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--headless")  # Run Chrome in headless mode (no UI)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Define stock names to scrape
companies = ["Deepak Nitrite", "Tata Chemicals", "Aarti Industries", "SRF"]
base_url = "https://www.moneycontrol.com/forum/{}/"

# Store scraped data
data = []

for company in companies:
    print(f"Scraping comments for {company}...")

    # Format URL
    url = base_url.format(company.replace(" ", "-").lower())

    # Open URL
    driver.get(url)
    time.sleep(5)  # Allow page to load

    # Parse page source
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # Find discussion comments
    comments = soup.find_all('div', class_="postItem_text_paragraph__3XhZQ")  

    # Extract text and store in list
    for comment in comments:
        data.append([company, comment.text.strip()])

# Close the browser
driver.quit()

# Save data to CSV
df = pd.DataFrame(data, columns=["Company", "Comment"])
df.to_csv("chemical_sector_sentiment.csv", index=False, encoding="utf-8")

print("✅ Data saved to chemical_sector_sentiment.csv")
# Out:
# Scraping comments for Deepak Nitrite...
# Scraping comments for Tata Chemicals...
# Scraping comments for Aarti Industries...
# Scraping comments for SRF...
# ✅ Data saved to chemical_sector_sentiment.csv

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import pandas as pd

# Set up Selenium WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--headless")  # Run in headless mode
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Define stock names to scrape
companies = ["Deepak Nitrite", "Tata Chemicals", "Aarti Industries", "SRF"]
base_url = "https://www.moneycontrol.com/forum/{}/"

# Store scraped data
data = []

for company in companies:
    print(f"Scraping comments for {company}...")

    # Format URL
    url = base_url.format(company.replace(" ", "-").lower())

    # Open URL
    driver.get(url)
    time.sleep(10)  # Allow page to load completely

    # Scroll down to load more comments
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)

    # Parse page source
    soup = BeautifulSoup(driver.page_source, 'html.parser')

    # DEBUG: Print page HTML to check if comments are present
    print(soup.prettify())  

    # Find discussion comments (Update the class name if needed)
    comments = soup.find_all('div', class_="postItem_text_paragraph__3XhZQ")  

    # Extract text and store in list
    for comment in comments:
        data.append([company, comment.text.strip()])

# Close the browser
driver.quit()

# Save data to CSV
df = pd.DataFrame(data, columns=["Company", "Comment"])
df.to_csv("chemical_sector_sentiment.csv", index=False, encoding="utf-8")

print("✅ Data saved to chemical_sector_sentiment.csv")
# Out:
# Scraping comments for Deepak Nitrite...
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
#  </head>
#  <body>
#   <h1>
#    Access Denied
#   </h1>
#   You don't have permission to access "http://www.moneycontrol.com/forum/deepak-nitrite/" on this server.
#   <p>
#    Reference #18.9c4c3917.1742202082.88a7d611
#   </p>
#   <p>
#    https://errors.edgesuite.net/18.9c4c3917.1742202082.88a7d611
#   </p>
#  </body>
# </html>
#
# Scraping comments for Tata Chemicals...
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
#  </head>
#  <body>
#   <h1>
#    Access Denied
#   </h1>
#   You don't have permission to access "http://www.moneycontrol.com/forum/tata-chemicals/" on this server.
#   <p>
#    Reference #18.9c4c3917.1742202099.88aa321b
#   </p>
#   <p>
#    https://errors.edgesuite.net/18.9c4c3917.1742202099.88aa321b
#   </p>
#  </body>
# </html>
#
# Scraping comments for Aarti Industries...
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
# ...

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Referer": "https://www.moneycontrol.com/",
    "Accept-Language": "en-US,en;q=0.9",
     URL of the Moneycontrol forum page for a chemical sector company
url = "https://www.moneycontrol.com/forum/tata-chemicals/"

# Send the request
response = requests.get(url, headers=headers)

# Check if request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")
    
    # Extract comments based on the class name
    comments = soup.find_all('div', class_="postItem_text_paragraph__3XhZQ")

    # Print comments to check if scraping works
    for i, comment in enumerate(comments[:10], 1):  # Limiting to first 10 comments
        print(f"{i}. {comment.text.strip()}")
else:
    print("Blocked or Access Denied:", response.status_code)
}
# Out:
#   Cell In[24], line 5
#     URL of the Moneycontrol forum page for a chemical sector company
#       ^
# SyntaxError: ':' expected after dictionary key

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.moneycontrol.com/forum/tata-chemicals/"
response = requests.get(url, headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")
    print(soup.prettify())  # Check if comments are present
else:
    print("Blocked:", response.status_code)
# Out:
# Blocked: 503

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Configure Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run Chrome in headless mode (no UI)
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")

# Set up WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# List of chemical companies (replace with forum URLs)
companies = {
    "Deepak Nitrite": "https://www.moneycontrol.com/forum/deepak-nitrite/",
    "Tata Chemicals": "https://www.moneycontrol.com/forum/tata-chemicals/",
    "Aarti Industries": "https://www.moneycontrol.com/forum/aarti-industries/",
    "SRF": "https://www.moneycontrol.com/forum/srf/"
}

# List to store data
data = []

# Scraping each company's forum page
for company, url in companies.items():
    print(f"Scraping comments for {company}...")
    
    try:
        driver.get(url)
        time.sleep(5)  # Wait for the page to load

        # Find all comment elements (modify if needed)
        comments = driver.find_elements(By.CLASS_NAME, "postItem_text_paragraph__3XhZQ")
        
        # Extract comment text
        for comment in comments:
            text = comment.text.strip()
            if text:  # Ignore empty comments
                data.append([company, text])

    except Exception as e:
        print(f"Error scraping {company}: {e}")

# Close the browser
driver.quit()

# Save data to CSV
df = pd.DataFrame(data, columns=["Company", "Comment"])
df.to_csv("chemical_sector_sentiment.csv", index=False, encoding="utf-8")

print("✅ Data saved to chemical_sector_sentiment.csv")
# Out:
# Scraping comments for Deepak Nitrite...
# Scraping comments for Tata Chemicals...
# Scraping comments for Aarti Industries...
# Scraping comments for SRF...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[25], line 56
#      54 # Save data to CSV
#      55 df = pd.DataFrame(data, columns=["Company", "Comment"])
# ---> 56 df.to_csv("chemical_sector_sentiment.csv", index=False, encoding="utf-8")
#      58 print("✅ Data saved to chemical_sector_sentiment.csv")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# ...

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Configure Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in background
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")

# Spoof user-agent to bypass bot detection
chrome_options.add_argument(
    "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.199 Safari/537.36"
)

# Set up WebDriver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# List of chemical companies (replace with actual forum URLs)
companies = {
    "Deepak Nitrite": "https://www.moneycontrol.com/forum/deepak-nitrite/",
    "Tata Chemicals": "https://www.moneycontrol.com/forum/tata-chemicals/",
    "Aarti Industries": "https://www.moneycontrol.com/forum/aarti-industries/",
    "SRF": "https://www.moneycontrol.com/forum/srf/"
}

# List to store data
data = []

# Scraping each company's forum page
for company, url in companies.items():
    print(f"Scraping comments for {company}...")

    try:
        driver.get(url)
        time.sleep(5)  # Wait for page to load

        # Scroll down to load more comments
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)

        # Find all comments
        comments = driver.find_elements(By.CLASS_NAME, "postItem_text_paragraph__3XhZQ")
        
        # Extract comment text
        for comment in comments:
            text = comment.text.strip()
            if text:
                data.append([company, text])

    except Exception as e:
        print(f"Error scraping {company}: {e}")

# Close browser
driver.quit()

# Save data to CSV
df = pd.DataFrame(data, columns=["Company", "Comment"])
df.to_csv("chemical_sector_sentiment.csv", index=False, encoding="utf-8")

print("✅ Data saved to chemical_sector_sentiment.csv")
# Out:
# Scraping comments for Deepak Nitrite...
# Scraping comments for Tata Chemicals...
# Scraping comments for Aarti Industries...
# Scraping comments for SRF...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[26], line 65
#      63 # Save data to CSV
#      64 df = pd.DataFrame(data, columns=["Company", "Comment"])
# ---> 65 df.to_csv("chemical_sector_sentiment.csv", index=False, encoding="utf-8")
#      67 print("✅ Data saved to chemical_sector_sentiment.csv")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# ...

# %%
import tweepy 
import json 
from datetime import date, timedelta, datetime 
from pymongo import MongoClient 
from html.parser import HTMLParser 
import re 
from pyshorteners import Shortener 


NewsArrayIndex = 0
NewsArray = [None] * 3

class MyHTMLParser(HTMLParser): 
	
	# This function collects the value 
	# of href and stores in NewsArrayIndex 
	# variable 
	def handle_starttag(self, tag, attrs): 
		
		# Only parse the 'anchor' tag. 
		global NewsArrayIndex 
		if tag == "a": 
			
			# Check the list of defined attributes. 
			for name, value in attrs: 
				
				# If href is defined, print it. 
				if name == "href": 
					
					# print(value + "\t" + News1)								 
					NewsArray[NewsArrayIndex] = value 
					
					# print(NewsArray) 
					NewsArrayIndex += 1

# %%
# pip install pyshorteners
# # pip install pymongo
# # pip install tweepy
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for pyshorteners: filename=pyshorteners-1.0.1-py3-none-any.whl size=17562 sha256=0542176a678f3aa8041b7028f69f1449cf3855fb893d39ef403a7afa347d9342
#   Stored in directory: c:\users\tanma\appdata\local\pip\cache\wheels\30\e9\7c\06d5ea1c320274f44cc35321a75198e266b2d47b3092aa9b7e
# Successfully built pyshorteners
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
NewsArrayIndex = 0
NewsArray = [None] * 3

# %%
# Driver Code 
News1 = ' '
News2 = ' '

date_str = str(date.today()) 
print("today", date_str) 
client = MongoClient('mongodb://localhost:27017/') 

# Connect your database here 
db1 = client.xxxx 

# credentials to tweet 
consumer_key = "VrsdYlXxjFd6KVKro6scC3GVE" #API "xxxx"
consumer_secret ="IUNjHwp8c1SSzlukUm7MBPLudxHuQgC5Y0bdLCIfWZB5F85IId" #API SEC
access_token = "808993512993816576-HQWxHArM3pKQA0NhYPXoLt7zFXGiMUS"
# "AAAAAAAAAAAAAAAAAAAAADiR0AEAAAAA4Mf2xQUdKiO3SLKt9dx35OFtRYs%3DRLE1nJ58ich1Wo5UF8XCoxgINRdh1ic6sMWfF8B6A7a19OOYTW" #"xxxx"
access_token_secret ="QWbVJErKeFBQTTfLPrAst5NOCLkol1dIEiTNCfdpMFKc7"

# authentication of consumer key and secret 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 

# authentication of access token and secret 
auth.set_access_token(access_token, access_token_secret)
# Out:
# today 2025-03-24
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 24
#      22 # authentication of access token and secret
#      23 auth.set_access_token(access_token, access_token_secret)
# ---> 24 api = tweepy.API(auth,
#      25 				wait_on_rate_limit = True,
#      26 				wait_on_rate_limit_notify = True)
#
# TypeError: API.__init__() got an unexpected keyword argument 'wait_on_rate_limit_notify'

# %%
api = tweepy.API(auth, 
				wait_on_rate_limit = True #, 
				# wait_on_rate_limit_notify = True
    )

# %%
cursor_P = db1.Coll_DailyNewsPlusReview.find({"time": date_str}) 
				
p0 = cursor_P[0] 
# News = p0.get('News')
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[24], line 3
#       1 cursor_P = db1.Coll_DailyNewsPlusReview.find({"time": date_str})
# ----> 3 p0 = cursor_P[0]
#       4 # News = p0.get('News')
#
# File c:\Users\tanma\Desktop\GIT_PUSH\Python_Project\WebScraping\clean_env\Lib\site-packages\pymongo\synchronous\cursor.py:638, in Cursor.__getitem__(self, index)
#     636 clone.limit(-1)  # use a hard limit
#     637 clone._query_flags &= ~CursorType.TAILABLE_AWAIT  # PYTHON-1371
# --> 638 for doc in clone:  # type: ignore[attr-defined]
#     639     return doc
#     640 raise IndexError("no such item for Cursor instance")
#
# File c:\Users\tanma\Desktop\GIT_PUSH\Python_Project\WebScraping\clean_env\Lib\site-packages\pymongo\synchronous\cursor.py:1281, in Cursor.__next__(self)
#    1280 def __next__(self) -> _DocumentType:
# -> 1281     return self.next()
#
# ...

# %%
News = p0.get('ChemicalStocks')
print(News)

# %%
def tweetDailyNews(): 
	
	try: 
		
		# This is the collection name in mongodb 
		cursor_P = db1.Coll_DailyNewsPlusReview.find({"time": date_str}) 
				
		p0 = cursor_P[0] 
		News = p0.get('News') 
		sortedNews = sorted(News, key = lambda x: int(x[1]), reverse = True) 
		print(sortedNews[0][0]+"--" + sortedNews[0][1], 
			sortedNews[1][0] + ".."+ sortedNews[1][1], 
			sortedNews[2][0] + ".." + sortedNews[2][1]) 
		
		hyperlink_format = '<a href ="{link}">{text}</a>'
		parser = MyHTMLParser() 
		dailyNews = "Impactful News of the Day" + "\n"
		
		News0 = sortedNews[0][2] 
		parser.feed(hyperlink_format.format(link = News0, text = News0)) 
		
		News1 = sortedNews[1][2] 
		print("News1", News1) 
		parser.feed(hyperlink_format.format(link = News1, text = News1)) 
		
		News2 = sortedNews[2][2] 
		print(News2) 
		parser.feed(hyperlink_format.format(link = News2, text = News2)) 
		
		# News shortening pattern 
		BITLY_ACCESS_TOKEN ="20dab258cc44c7d017bcd1c1f4b24484a37b8de9"
		b = Shortener(api_key = ACCESS_TOKEN) 
		
		NewsArray[0] = re.sub('\n', '', NewsArray[0]) 
		response1 = b.bitly.short(NewsArray[0]) 
		response1 = response1['url'] 
		
		NewsArray[1] = re.sub('\n', '', NewsArray[1]) 
		response2 = b.bitly.short(NewsArray[1]) 
		response2 = response2['url'] 
		
		NewsArray[2] = re.sub('\n', '', NewsArray[2]) 
		response3 = b.bitly.short(NewsArray[2]) 
		response3 = response3['url'] 
		
		news1FewWords = sortedNews[0][0].split() 
		dailyNews += news1FewWords[0] + " "
		+ news1FewWords[1] + " " + news1FewWords[2] 
		+ "...." + response1 + "\n"
		
		news2FewWords = sortedNews[1][0].split() 
		dailyNews += news2FewWords[0] + " "
		+ news2FewWords[1] + " " + news2FewWords[2] 
		+ "...." + response2+"\n"
		
		news3FewWords = sortedNews[2][0].split() 
		dailyNews += news3FewWords[0] + " "
		+ news3FewWords[1] + " " + news3FewWords[2] 
		+ "...." + response3 + "\n" + "# bitcoin \ 
		# cryptocurrency # blockchain # investor # altcoins\ 
		# fintech # investment" 
		print(dailyNews) 
		
		status = api.update_status(status = dailyNews) 
		if status: 
			for i in range(3): 
				datas = {} 
				datas['time'] = str(date.today()) 
				datas['posted_as'] = i 
				datas['news'] = sortedNews[i][0] 
				datas['shortenedlink'] = NewsArray[i] 
				datas['reviewcount'] = sortedNews[i][1] 
				datas['link'] = sortedNews[i][2] 
				db1.Collection_tweeted_news.insert(datas) 
				
			
	except Exception as e: 
		print(e) 
		print("Error in getting today news data", str(date_str)) 

		
# Driver Code 
News1 = ' '
News2 = ' '

date_str = str(date.today()) 
print("today", date_str) 
client = MongoClient('mongodb://localhost:27017/') 

# Connect your database here 
db1 = client.xxxx 

# credentials to tweet 
consumer_key ="xxxx"
consumer_secret ="xxxx"
access_token ="xxxx"
access_token_secret ="xxxx"

# authentication of consumer key and secret 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 

# authentication of access token and secret 
auth.set_access_token(access_token, access_token_secret) 
api = tweepy.API(auth, 
				wait_on_rate_limit = True, 
				wait_on_rate_limit_notify = True) 
	
tweetDailyNews()

# %%
# Python program to get top 3 trendy news item 


import tweepy 
import json 
from datetime import date, timedelta, datetime 
from pymongo import MongoClient 
from html.parser import HTMLParser 
import re 
from pyshorteners import Shortener 


NewsArrayIndex = 0
NewsArray = [None] * 3

class MyHTMLParser(HTMLParser): 
	
	# This function collects the value 
	# of href and stores in NewsArrayIndex 
	# variable 
	def handle_starttag(self, tag, attrs): 
		
		# Only parse the 'anchor' tag. 
		global NewsArrayIndex 
		if tag == "a": 
			
			# Check the list of defined attributes. 
			for name, value in attrs: 
				
				# If href is defined, print it. 
				if name == "href": 
					
					# print(value + "\t" + News1)								 
					NewsArray[NewsArrayIndex] = value 
					
					# print(NewsArray) 
					NewsArrayIndex += 1
					
# This function is the primary place 
# to tweet the collected daily news 
# News is retrieved from Coll_DailyNewsPlusReview 
# collection (MongoDB collection) This collection 
# holds the value of " News Headlines, Its review 
# count, news link" and based upon the review count, 
# top most # reviewed news are taken As twitter allows 
# only 280 characters, the retrieved news link got 
# shortened by using BITLY API Hashtags related to 
# the news are added underneath the retrieved top 
# 3 news (All together allowed characters are 280) 
# Then top 3 news gets tweeted from a credential 
# Finally per day basis the tweeted news are stored 
# into another collection for audit purposes as well 
# as for weekly posting 
def tweetDailyNews(): 
	
	try: 
		
		# This is the collection name in mongodb 
		cursor_P = db1.Coll_DailyNewsPlusReview.find({"time": date_str}) 
				
		p0 = cursor_P[0] 
		News = p0.get('News') 
		sortedNews = sorted(News, key = lambda x: int(x[1]), reverse = True) 
		print(sortedNews[0][0]+"--" + sortedNews[0][1], 
			sortedNews[1][0] + ".."+ sortedNews[1][1], 
			sortedNews[2][0] + ".." + sortedNews[2][1]) 
		
		hyperlink_format = '<a href ="{link}">{text}</a>'
		parser = MyHTMLParser() 
		dailyNews = "Impactful News of the Day" + "\n"
		
		News0 = sortedNews[0][2] 
		parser.feed(hyperlink_format.format(link = News0, text = News0)) 
		
		News1 = sortedNews[1][2] 
		print("News1", News1) 
		parser.feed(hyperlink_format.format(link = News1, text = News1)) 
		
		News2 = sortedNews[2][2] 
		print(News2) 
		parser.feed(hyperlink_format.format(link = News2, text = News2)) 
		
		# News shortening pattern 
		BITLY_ACCESS_TOKEN ="20dab258cc44c7d017bcd1c1f4b24484a37b8de9"
		b = Shortener(api_key = ACCESS_TOKEN) 
		
		NewsArray[0] = re.sub('\n', '', NewsArray[0]) 
		response1 = b.bitly.short(NewsArray[0]) 
		response1 = response1['url'] 
		
		NewsArray[1] = re.sub('\n', '', NewsArray[1]) 
		response2 = b.bitly.short(NewsArray[1]) 
		response2 = response2['url'] 
		
		NewsArray[2] = re.sub('\n', '', NewsArray[2]) 
		response3 = b.bitly.short(NewsArray[2]) 
		response3 = response3['url'] 
		
		news1FewWords = sortedNews[0][0].split() 
		dailyNews += news1FewWords[0] + " "
		+ news1FewWords[1] + " " + news1FewWords[2] 
		+ "...." + response1 + "\n"
		
		news2FewWords = sortedNews[1][0].split() 
		dailyNews += news2FewWords[0] + " "
		+ news2FewWords[1] + " " + news2FewWords[2] 
		+ "...." + response2+"\n"
		
		news3FewWords = sortedNews[2][0].split() 
		dailyNews += news3FewWords[0] + " "
		+ news3FewWords[1] + " " + news3FewWords[2] 
		+ "...." + response3 + "\n" + "# bitcoin \ 
		# cryptocurrency # blockchain # investor # altcoins\ 
		# fintech # investment" 
		print(dailyNews) 
		
		status = api.update_status(status = dailyNews) 
		if status: 
			for i in range(3): 
				datas = {} 
				datas['time'] = str(date.today()) 
				datas['posted_as'] = i 
				datas['news'] = sortedNews[i][0] 
				datas['shortenedlink'] = NewsArray[i] 
				datas['reviewcount'] = sortedNews[i][1] 
				datas['link'] = sortedNews[i][2] 
				db1.Collection_tweeted_news.insert(datas) 
				
			
	except Exception as e: 
		print(e) 
		print("Error in getting today news data", str(date_str)) 

		
# Driver Code 
News1 = ' '
News2 = ' '

date_str = str(date.today()) 
print("today", date_str) 
client = MongoClient('mongodb://localhost:27017/') 

# Connect your database here 
db1 = client.xxxx 

# credentials to tweet 
consumer_key ="xxxx"
consumer_secret ="xxxx"
access_token ="xxxx"
access_token_secret ="xxxx"

# authentication of consumer key and secret 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 

# authentication of access token and secret 
auth.set_access_token(access_token, access_token_secret) 
api = tweepy.API(auth, 
				wait_on_rate_limit = True, 
				wait_on_rate_limit_notify = True) 
	
tweetDailyNews()
